# %% [markdown]
# # Multi variete representation of continuous variables
#
# For this part, we will use the following dataset: <a href="" target="_blank">sales_predictions.csv</a>

# %% [markdown]
# 1. Import usual librairies

# %%
import pandas as pd, matplotlib.pyplot as plt

# %%
data_df = pd.read_csv("./data/sales_predictions.csv")

# %%
data_df.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0     59.0  22154.0      999.00           1.0
# 1  03.01.2013               0     25.0   2552.0      899.00           1.0
# 2  05.01.2013               0     25.0   2552.0      899.00          -1.0
# 3  06.01.2013               0     25.0   2554.0     1709.05           1.0
# 4  15.01.2013               0     25.0   2555.0     1099.00           1.0

# %% [markdown]
# 2. Use a ```sample()``` to select 25 random entries from the dataset

# %%
data_df_red = data_df.sample(25)

# %% [markdown]
# 3. Use ```relplot()``` to build a chart that will allow you to see the price evolution over time. What can you see?

# %% [markdown]
# 4. Using the ```pd.to_datetime()``` function, convert your ```date``` column to ```datetime``` format.

# %%
# Out:
# 1077079   2013-09-11
# 622227    2013-06-20
# 456424    2013-06-05
# 623995    2013-06-20
# 2379513   2015-01-14
# 2672828   2015-10-06
# 920197    2013-09-17
# 1664977   2014-05-22
# 2694948   2015-02-06
# 1537517   2014-03-15
# 1839027   2014-07-30
# 1413702   2014-09-02
# 1262484   2013-12-22
# 257776    2013-03-24
# 1861565   2014-07-25
# 1451      2013-04-01
# 2861252   2015-06-09
# 297435    2013-03-17
# 1487859   2014-03-29
# 2069682   2014-09-10
# 2362784   2015-07-01
# 874483    2013-06-09
# 2753961   2015-02-07
# 2898678   2015-10-18
# 2456396   2015-07-02
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# 5. Retry doing your visualization. What do you see?
