# %% [markdown]
# # Visualization of categorical variables
#
# For this part, we will use the following dataset: <a href="https://full-stack-bigdata-datasets.s3.eu-west-3.amazonaws.com/Data+visualisation+et+collaboration/M03.D02/IBM_HR_ATTRITION.csv" target="_blank">```IBM_HR_ATTRITION.csv```</a>.

# %% [markdown]
# 1. Import usual librairies

# %%
import pandas as pd, matplotlib.pyplot as plt, seaborn as sns

# %% [markdown]
# 2. Preview the dataset to become familiar with it.

# %%
data_df = pd.read_csv("./data/IBM_HR_ATTRITION.csv")

# %%
data_df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data_df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# 3. Using ```catplot()```, construct a graph that allows you to check if the distribution ```JobSatisfaction``` is different for people who left the company compared to people who didn't: ```Attrition```.

# %%
data_df.select_dtypes(exclude="number")
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
sns.boxplot(data=data_df, x='Attrition', y='JobSatisfaction')
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='JobSatisfaction'>

# %%
sns.catplot(data= data_df, x="Attrition", y="Age", hue="Department", height=4, aspect=1.7, kind='box')

# %%
sns.boxplot(data= data_df, x="Attrition", y="TotalWorkingYears")
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='TotalWorkingYears'>

# %%
sns.catplot(data=data_df, x="JobSatisfaction", y="TotalWorkingYears", kind="box", hue="Attrition", height=4, aspect=1.7)

# %%
data_df["JobSatisfaction"].describe()
# Out:
# count    1470.000000
# mean        2.728571
# std         1.102846
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64

# %%
sns.catplot(data=data_df, x="Attrition", y="TotalWorkingYears", hue="JobSatisfaction", kind="box", height=4, aspect=1.7)

# %%
sns.boxplot(data=data_df, x='Attrition', y='TotalWorkingYears')
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='TotalWorkingYears'>

# %% [markdown]
# 4. Is it possible to tell from the boxplots whether a variable has outliers?

# %%
"""
WRITE YOUR ANSWER HERE
Yes, it is the idea of boxplots.
"""

# %% [markdown]
# 5. Isolate observations with outliers for the ```TotalWorkingYears``` variable according to the variable indicating whether they left the company or name

# %%
stats_working_df = data_df.groupby("Attrition")["TotalWorkingYears"].describe().T

# %%
stats_working_df
# Out:
# Attrition           No         Yes
# count      1233.000000  237.000000
# mean         11.862936    8.244726
# std           7.760719    7.169204
# min           0.000000    0.000000
# 25%           6.000000    3.000000
# 50%          10.000000    7.000000
# 75%          16.000000   10.000000
# max          38.000000   40.000000

# %%
stats_working_df.loc["75%"]
# Out:
# Attrition
# No     16.0
# Yes    10.0
# Name: 75%, dtype: float64

# %%
data_df[["Attrition", "TotalWorkingYears"]].iloc[(data_df["Attrition"] == "Yes") & (data_df["TotalWorkingYears"])]
# Out:
#      Attrition  TotalWorkingYears
# 0          Yes                  8
# 1           No                 10
# 2          Yes                  7
# 3           No                  8
# 4           No                  6
# ...        ...                ...
# 1465        No                 17
# 1466        No                  9
# 1467        No                  6
# 1468        No                 17
# 1469        No                  6
#
# [1470 rows x 2 columns]

# %%
(stats_working_df.loc['75%'] - stats_working_df.loc['25%'])
# Out:
# Attrition
# No     10.0
# Yes     7.0
# dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.set(rc={'figure.figsize':(10,10)})

# %%
sns.boxplot(data=data_df, x="Attrition", y="TotalWorkingYears")
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='TotalWorkingYears'>

# %%
plt.figure()
fig, ax = plt.subplots(1,2)

# %%
type(ax[0])
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# 6. Use pandas' `.describe()` method to obtain a summary table of descriptive statistics for the dataset.

# %%
data_df["YearsAtCompany"].describe()
# Out:
# count    1470.000000
# mean        7.008163
# std         6.126525
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         9.000000
# max        40.000000
# Name: YearsAtCompany, dtype: float64

# %% [markdown]
# 7. Compare the individuals with outliers for the variable ```YearsAtCompany``` with the descriptive statistics from the dataset, do you notice any significant differences?

# %% [markdown]
# 8. Replace the values in the ```Attrition``` column with ```1``` for ```Yes``` and ```0``` for ```No```.
#
# Let's have a preview of your column.

# %%
data_df["Attrition_1"] = [1 if x == "Yes" else 0 for x in data_df["Attrition"]]

# %%
data_df["Attrition_1"].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition_1, dtype: int64

# %% [markdown]
# 9. Using a bar plot, look at the distribution of the ```Attrition``` rate by ```EducationField```.

# %%
fig, catplot = plt.subplots(figsize = (11,7))

# %%
fig = plt.figure(figsize=(20,20))

# %%
fig, ax = plt.subplots(figsize=(20, 10))

# %%
sns.countplot(data=data_df, x="EducationField", kind="count", hue="Attrition", ax=ax);
plt.show()

# %%
data_df.groupby(["EducationField", "Attrition_1"]).count()
# Out:
#                               Age  Attrition  BusinessTravel  DailyRate  \
# EducationField   Attrition_1
# Human Resources  0             20         20              20         20
#                  1              7          7               7          7
# Life Sciences    0            517        517             517        517
#                  1             89         89              89         89
# Marketing        0            124        124             124        124
#                  1             35         35              35         35
# Medical          0            401        401             401        401
#                  1             63         63              63         63
# Other            0             71         71              71         71
#                  1             11         11              11         11
# Technical Degree 0            100        100             100        100
#                  1             32         32              32         32
#
# ...
