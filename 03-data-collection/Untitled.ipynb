# %%
import requests

# %%
result = requests.get("https://api.github.com/repos/mlflow/mlflow/branches")

# %%
result
# Out:
# <Response [200]>

# %%
dict_res = result.json()

# %%
dict_res
# Out:
# [{'name': '0.9',
#   'commit': {'sha': 'dbd1bcffce4b7e2c76ec3578e187601576e3f26d',
#    'url': 'https://api.github.com/repos/mlflow/mlflow/commits/dbd1bcffce4b7e2c76ec3578e187601576e3f26d'},
#   'protected': False},
#  {'name': '2019-12-19-22-52-30-048977',
#   'commit': {'sha': '53b1b5987ba5cb660ced3c67e47ae13787b742b6',
#    'url': 'https://api.github.com/repos/mlflow/mlflow/commits/53b1b5987ba5cb660ced3c67e47ae13787b742b6'},
#   'protected': False},
#  {'name': '2019-12-19-23-00-42-155563',
#   'commit': {'sha': 'ecb5ff478726f4abf95677ee91a1c03cc1950fe9',
#    'url': 'https://api.github.com/repos/mlflow/mlflow/commits/ecb5ff478726f4abf95677ee91a1c03cc1950fe9'},
#   'protected': False},
#  {'name': 'ES-76753',
#   'commit': {'sha': '918b107f00cbc7ea08810e59de0eb496cb0384a3',
#    'url': 'https://api.github.com/repos/mlflow/mlflow/commits/918b107f00cbc7ea08810e59de0eb496cb0384a3'},
#   'protected': False},
#  {'name': 'ML-10377',
# ...

# %%
result2 = requests.get("https://api.github.com/users/mateiz/subscriptions")
dict_res2 = result2.json()

# %%
dict_res2
# Out:
# [{'id': 510475,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk1MTA0NzU=',
#   'name': 'pig',
#   'full_name': 'dvryaboy/pig',
#   'private': False,
#   'owner': {'login': 'dvryaboy',
#    'id': 103698,
#    'node_id': 'MDQ6VXNlcjEwMzY5OA==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103698?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dvryaboy',
#    'html_url': 'https://github.com/dvryaboy',
#    'followers_url': 'https://api.github.com/users/dvryaboy/followers',
#    'following_url': 'https://api.github.com/users/dvryaboy/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dvryaboy/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dvryaboy/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dvryaboy/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dvryaboy/orgs',
#    'repos_url': 'https://api.github.com/users/dvryaboy/repos',
# ...

# %%
result3 = requests.get("https://api.github.com/users/cyrmonti/following")
result3.json()
# Out:
# [{'login': 'ClementTr',
#   'id': 17518654,
#   'node_id': 'MDQ6VXNlcjE3NTE4NjU0',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/17518654?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ClementTr',
#   'html_url': 'https://github.com/ClementTr',
#   'followers_url': 'https://api.github.com/users/ClementTr/followers',
#   'following_url': 'https://api.github.com/users/ClementTr/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ClementTr/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ClementTr/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ClementTr/subscriptions',
#   'organizations_url': 'https://api.github.com/users/ClementTr/orgs',
#   'repos_url': 'https://api.github.com/users/ClementTr/repos',
#   'events_url': 'https://api.github.com/users/ClementTr/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/ClementTr/received_events',
# ...
